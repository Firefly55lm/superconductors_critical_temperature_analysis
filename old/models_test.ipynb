# %% [markdown]
# ### LIBRARIES

# %%
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D
from matplotlib.colors import ListedColormap
from utilities.utils import load_sns_theme

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### DATASET

# %%
df = pd.read_csv("data\superconductivity.csv")
df
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.257143       2.213364
# 1            47.094633  ...          2.257143       1.888175
# 2            51.968828  ...          2.271429       2.213364
# 3            51.968828  ...          2.264286       2.213364
# 4            51.968828  ...          2.242857       2.213364
# ...                ...  ...               ...            ...
# 21258        65.764081  ...          3.555556       3.223710
# 21259        69.232655  ...          2.047619       2.168944
# 21260         6.756810  ...          4.800000       4.472136
# 21261         6.756810  ...          4.690000       4.472136
# 21262        29.905282  ...          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 0               1.085714     0.433013         0.437059          29.00
# 1               1.128571     0.632456         0.468606          26.00
# 2               1.114286     0.433013         0.444697          19.00
# 3               1.100000     0.433013         0.440952          22.00
# 4               1.057143     0.433013         0.428809          23.00
# ...                  ...          ...              ...            ...
# 21258           2.168889     0.433013         0.496904           2.44
# 21259           0.904762     0.400000         0.212959         122.10
# 21260           3.200000     0.500000         0.400000           1.98
# 21261           2.210000     0.500000         0.462493           1.84
# 21262           1.800000     1.414214         1.500000          12.80
#
# [21263 rows x 82 columns]

# %%
y = df[["critical_temp"]]
df = df.drop(columns=["critical_temp"])

# %% [markdown]
# ### SEABORN THEME

# %%
load_sns_theme(r"utilities\themes\fire_theme_full_dark.json")
# Out:
# {'figure.facecolor': '#202021',
#  'axes.facecolor': '#262626',
#  'axes.edgecolor': '#cfcfd1',
#  'axes.grid': True,
#  'grid.color': '#555555',
#  'grid.linewidth': 0.5,
#  'xtick.color': '#ffffff',
#  'ytick.color': '#ffffff',
#  'axes.labelcolor': '#ffffff'}

# %% [markdown]
# ### MODELS

# %% [markdown]
# Standardize features

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %% [markdown]
# Model definition and fit

# %%
pca = PCA(n_components=5)

# %%
X_pca = pca.fit_transform(df_scaled)

# %% [markdown]
# All dimensions plot

# %%
sns.scatterplot(
    data=X_pca, legend=False
)
# Out:
# <Axes: >

# %% [markdown]
# First 3 dimensions plot

# %%
def get_features_name_from_dim(feature_names: list, pca_model, dimension: int):

    coefficients_dict = {feature_names[i]: pca_model.components_[dimension][i] for i in range(len(feature_names))}
    coefficients_dict = dict(sorted(coefficients_dict.items(), key=lambda x: abs(x[1]), reverse=True))

    print(f"\nCoefficients for Dimension {dimension}:")
    print(coefficients_dict)

    return coefficients_dict

# %%
feature_names = df.columns

coeff_0 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=0)

coeff_1 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=1)

coeff_2 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=2)
# Out:
# Coefficients for Dimension 0:
# {'range_fie': -0.16397827647759627, 'wtd_std_fie': -0.16348764769239385, 'range_atomic_radius': -0.1634811625790562, 'wtd_entropy_atomic_radius': -0.16345692130404693, 'wtd_std_atomic_radius': -0.16047256302226875, 'entropy_Valence': -0.1587464651307681, 'entropy_fie': -0.1566215795530771, 'wtd_entropy_atomic_mass': -0.1564645556235142, 'wtd_entropy_Valence': -0.15601224142456432, 'number_of_elements': -0.1557783290521591, 'wtd_gmean_Density': 0.15564022315714263, 'std_fie': -0.1553437471172159, 'entropy_atomic_radius': -0.1533936897818148, 'gmean_Density': 0.1504819824215825, 'std_atomic_radius': -0.14970272803184323, 'wtd_gmean_Valence': 0.14662669182409138, 'entropy_atomic_mass': -0.14641853528074278, 'wtd_mean_Valence': 0.14456890895564395, 'range_ThermalConductivity': -0.1432876098929268, 'wtd_entropy_FusionHeat': -0.14307348824604524, 'gmean_Valence': 0.14108114411090925, 'entropy_ElectronAffinity': -0.14001682948910152, 'mean_Valence': 0.13968590229492003, 'wtd_std_ThermalConductivity': -0.13875181059666822, 'wtd_gmean_atomic_radius': 0.13808598905719582, 'std_ThermalConductivity': -0.13443365150938505, 'entropy_FusionHeat': -0.13405306568362652, 'wtd_mean_Density': 0.13100492932916133, 'wtd_mean_fie': -0.1289986689563661, 'range_atomic_mass': -0.1244774565582481, 'entropy_Density': -0.12188089781755809, 'wtd_gmean_atomic_mass': 0.1200636715682973, 'wtd_mean_atomic_radius': 0.1198704246447451, 'wtd_gmean_fie': -0.11742512389083612, 'wtd_entropy_Density': -0.11600845347163057, 'gmean_FusionHeat': 0.11537562498024762, 'wtd_gmean_FusionHeat': 0.11458973343014196, 'wtd_std_atomic_mass': -0.11276665094368951, 'wtd_entropy_fie': -0.11012134185503872, 'gmean_ThermalConductivity': 0.10970899784729007, 'mean_Density': 0.10891485202414622, 'wtd_range_Valence': 0.10791721582835731, 'wtd_gmean_ThermalConductivity': 0.10752924306977754, 'range_ElectronAffinity': -0.10458534602750633, 'wtd_std_ElectronAffinity': -0.10293422670631791, 'wtd_range_atomic_radius': 0.100754038019879, 'wtd_mean_atomic_mass': 0.09916961962625187, 'std_atomic_mass': -0.09849516173393066, 'wtd_mean_FusionHeat': 0.09662106155561183, 'wtd_entropy_ElectronAffinity': -0.09657184157030037, 'mean_FusionHeat': 0.0939472192205326, 'wtd_range_Density': 0.09348488052683816, 'std_ElectronAffinity': -0.09202354395185558, 'wtd_range_atomic_mass': 0.08788059175313634, 'wtd_range_fie': -0.08510511484712718, 'gmean_atomic_mass': 0.08332165792661073, 'gmean_atomic_radius': 0.07863906218457557, 'range_Density': -0.07562004403067552, 'wtd_range_FusionHeat': 0.07550652022069404, 'wtd_std_Density': -0.07153513082604748, 'wtd_range_ElectronAffinity': -0.06863139057742165, 'wtd_range_ThermalConductivity': -0.06124189937310608, 'wtd_mean_ElectronAffinity': -0.06074650782135323, 'mean_fie': -0.057073792992139126, 'gmean_ElectronAffinity': 0.05576868531801913, 'mean_ThermalConductivity': -0.051925874633929406, 'mean_atomic_mass': 0.05181304650944049, 'std_Density': -0.04083925046840751, 'entropy_ThermalConductivity': -0.03391669042647328, 'wtd_mean_ThermalConductivity': -0.02923191863692949, 'range_Valence': -0.026278187721642962, 'gmean_fie': -0.02354048642557178, 'mean_atomic_radius': 0.021117384884529484, 'std_FusionHeat': 0.020294734770476174, 'wtd_gmean_ElectronAffinity': -0.013108070511380883, 'wtd_std_FusionHeat': 0.010035071814349907, 'std_Valence': -0.008389451326841475, 'mean_ElectronAffinity': 0.006525561981244294, 'wtd_std_Valence': 0.0036007995163839035, 'range_FusionHeat': 0.0029931453904105177, 'wtd_entropy_ThermalConductivity': 0.0011910876959432086}
#
# Coefficients for Dimension 1:
# {'gmean_atomic_radius': -0.23001976318013057, 'mean_atomic_mass': -0.2264745927499113, 'mean_atomic_radius': -0.22323548085268155, 'gmean_atomic_mass': -0.21894420123167926, 'std_FusionHeat': 0.20450465466344178, 'wtd_mean_atomic_mass': -0.19990776876759345, 'wtd_std_FusionHeat': 0.19659734617084254, 'range_FusionHeat': 0.18635748497992832, 'wtd_gmean_atomic_mass': -0.18477968510410264, 'wtd_mean_atomic_radius': -0.17743333892874194, 'mean_fie': 0.17429605617356592, 'gmean_fie': 0.17211395108864144, 'entropy_FusionHeat': -0.16710019128925252, 'mean_Density': -0.1619829081798877, 'wtd_range_FusionHeat': 0.15765217007287055, 'wtd_gmean_atomic_radius': -0.15080667258378036, 'wtd_mean_FusionHeat': 0.1505093961744473, 'mean_FusionHeat': 0.1429831513693763, 'wtd_mean_Density': -0.14143752345602753, 'entropy_Density': -0.13557592298569793, 'wtd_gmean_fie': 0.13527257060569903, 'wtd_entropy_FusionHeat': -0.1282517201795591, 'entropy_atomic_mass': -0.12255116439773889, 'wtd_mean_fie': 0.1191811769051419, 'wtd_entropy_Density': -0.11821672675138617, 'wtd_range_atomic_mass': -0.1162685167288397, 'gmean_Density': -0.10982011489312998, 'wtd_gmean_FusionHeat': 0.10948505554294684, 'wtd_gmean_Density': -0.10381829774019445, 'entropy_atomic_radius': -0.10374316430459662, 'mean_ElectronAffinity': 0.0974092730320541, 'wtd_range_Density': -0.09415203838901945, 'entropy_ThermalConductivity': -0.09354540845068535, 'entropy_ElectronAffinity': -0.09256258309870964, 'number_of_elements': -0.09185595659372434, 'entropy_Valence': -0.0905663173472357, 'entropy_fie': -0.08910113227083498, 'range_Density': -0.08334840562018905, 'wtd_entropy_atomic_mass': -0.08272864706437448, 'wtd_gmean_ElectronAffinity': 0.0805346896521896, 'wtd_entropy_Valence': -0.0802026026835941, 'wtd_mean_ElectronAffinity': 0.07992187991590426, 'wtd_entropy_fie': -0.07970778919196467, 'range_atomic_mass': -0.07628393949079021, 'wtd_entropy_ElectronAffinity': -0.07515207558339167, 'gmean_ElectronAffinity': 0.07463127083589552, 'std_atomic_radius': 0.072551186609914, 'gmean_FusionHeat': 0.0690360899867533, 'wtd_std_ThermalConductivity': -0.06856970945637511, 'wtd_entropy_atomic_radius': -0.06755231019328617, 'std_Density': -0.06695149859936425, 'std_ElectronAffinity': 0.06658167233978066, 'wtd_range_atomic_radius': -0.06414221892584909, 'range_ThermalConductivity': -0.06314202625432948, 'std_atomic_mass': -0.06277877873750615, 'wtd_range_ThermalConductivity': -0.06187250676920542, 'std_fie': 0.06049091559943174, 'wtd_range_ElectronAffinity': 0.059238444672342364, 'wtd_std_Density': -0.05775223340232182, 'wtd_mean_ThermalConductivity': -0.05765185999314734, 'range_ElectronAffinity': 0.05368668454234698, 'std_ThermalConductivity': -0.050008202994172364, 'wtd_std_atomic_mass': -0.049296289161387806, 'wtd_entropy_ThermalConductivity': -0.04831109570235519, 'wtd_std_atomic_radius': 0.04476587639030744, 'wtd_range_fie': 0.041948278897752087, 'wtd_std_ElectronAffinity': 0.03813383770013083, 'gmean_Valence': -0.03415879344745965, 'wtd_std_fie': 0.030978819778769616, 'std_Valence': 0.029767563406931947, 'range_fie': 0.027404294991810605, 'mean_Valence': -0.02611156550563567, 'wtd_std_Valence': 0.02607287971605552, 'range_atomic_radius': 0.020791132165112126, 'gmean_ThermalConductivity': 0.02071380497121515, 'range_Valence': 0.02028177072994888, 'mean_ThermalConductivity': -0.016014054018288478, 'wtd_gmean_ThermalConductivity': 0.011978884095474804, 'wtd_range_Valence': -0.009441194603694195, 'wtd_gmean_Valence': -0.006408306157393081, 'wtd_mean_Valence': -0.002190671199614983}
#
# Coefficients for Dimension 2:
# {'wtd_entropy_ThermalConductivity': -0.24517858495200542, 'wtd_std_Valence': -0.23150078903928342, 'range_Valence': -0.22608712003266504, 'std_Valence': -0.2100471784704598, 'wtd_entropy_fie': -0.2060966801882916, 'entropy_ThermalConductivity': -0.20404171370219498, 'wtd_entropy_ElectronAffinity': -0.19292305594193795, 'range_FusionHeat': -0.18255227462019621, 'wtd_std_FusionHeat': -0.18001354265765185, 'std_FusionHeat': -0.17123241465749664, 'std_Density': -0.15784991969360912, 'wtd_range_fie': 0.14691549569818776, 'wtd_entropy_Density': -0.1455748178176735, 'range_Density': -0.14473119440246743, 'range_ElectronAffinity': -0.14448925112095595, 'mean_FusionHeat': -0.14202176234228664, 'wtd_mean_FusionHeat': -0.13626745505831486, 'std_ElectronAffinity': -0.13196387223411332, 'wtd_std_Density': -0.12952638547674672, 'gmean_fie': -0.12904908018557854, 'wtd_std_ElectronAffinity': -0.12731596155610403, 'wtd_mean_Valence': -0.12616061316833677, 'mean_ElectronAffinity': -0.12262594998245308, 'mean_Valence': -0.1218801343700731, 'std_ThermalConductivity': 0.11828183931591853, 'wtd_gmean_FusionHeat': -0.1167758573491498, 'std_atomic_mass': -0.11677030563943577, 'gmean_FusionHeat': -0.11117208174827645, 'wtd_gmean_Valence': -0.10880312628388138, 'mean_fie': -0.10828177555884642, 'wtd_std_ThermalConductivity': 0.10808018448369912, 'mean_atomic_radius': 0.10695329535777756, 'range_atomic_mass': -0.10593270105369038, 'wtd_entropy_Valence': -0.10412378473850387, 'range_ThermalConductivity': 0.10223113636992906, 'wtd_std_atomic_mass': -0.1011710203075471, 'wtd_mean_Density': -0.09789222811662406, 'gmean_Valence': -0.09746440403652218, 'entropy_fie': -0.09526729296594685, 'wtd_range_FusionHeat': -0.09448826544937933, 'entropy_atomic_radius': -0.09326826032908461, 'entropy_ElectronAffinity': -0.09173734152511441, 'entropy_Density': -0.08292546054628373, 'gmean_ElectronAffinity': -0.08042527638689345, 'wtd_entropy_FusionHeat': -0.07842078213935191, 'number_of_elements': -0.07519712091368758, 'wtd_entropy_atomic_radius': -0.07503501851588282, 'mean_Density': -0.0742377006063179, 'wtd_range_ThermalConductivity': 0.07394827630849377, 'gmean_atomic_radius': 0.07308429558076476, 'entropy_Valence': -0.0713025212621307, 'mean_ThermalConductivity': 0.06840063988559819, 'wtd_gmean_ThermalConductivity': -0.0667077435927772, 'wtd_mean_fie': 0.06661566136706633, 'wtd_gmean_Density': -0.06612854528593648, 'wtd_gmean_atomic_radius': -0.06573807334657022, 'wtd_range_Density': -0.06272109408271745, 'entropy_atomic_mass': -0.05972960712335464, 'wtd_gmean_fie': 0.05682791877398835, 'wtd_mean_atomic_radius': -0.055907891056292895, 'entropy_FusionHeat': -0.05536226222241383, 'wtd_mean_atomic_mass': -0.0550806642550785, 'gmean_Density': -0.05480408155229405, 'gmean_ThermalConductivity': -0.05150047512379571, 'wtd_range_atomic_mass': -0.05119458447869145, 'wtd_std_fie': 0.051186852500054364, 'wtd_entropy_atomic_mass': -0.04921636665956995, 'wtd_range_ElectronAffinity': 0.0484025435573116, 'wtd_range_Valence': -0.045755286019623365, 'wtd_std_atomic_radius': 0.03139449416107497, 'wtd_gmean_atomic_mass': -0.02865225481755266, 'gmean_atomic_mass': 0.0253254965744043, 'wtd_gmean_ElectronAffinity': 0.024490638810260753, 'wtd_mean_ThermalConductivity': 0.01798219011946531, 'range_atomic_radius': 0.014911412111393926, 'std_atomic_radius': 0.013802737492626631, 'wtd_range_atomic_radius': -0.011749558804670358, 'wtd_mean_ElectronAffinity': -0.0099421000760492, 'mean_atomic_mass': -0.007334315887144455, 'std_fie': 0.007238059184249992, 'range_fie': -0.0047325690634421914}

# %%
from matplotlib.colors import Normalize

norm = Normalize(vmin=0, vmax=100)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=X_pca[:, 0], ys=X_pca[:, 1], zs=X_pca[:, 2],
           c=y["critical_temp"].ravel(), cmap="rocket", norm=norm, s=2, alpha=0.6)

ax.set_xlabel('Dimension 0')
ax.set_ylabel('Dimension 1')
ax.set_zlabel('Dimension 2')
ax.set_title('3D PCA scatter for first 3 dimensions', color="white")

legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#251432', markersize=10, label='Low'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#c6004e', markersize=10, label='Medium'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#f5c5ac', markersize=10, label='High')
]

legend = ax.legend(handles=legend_elements, title="Critical temperature", loc='upper left', labels=['Low', 'Medium', 'High'])
for text in legend.get_texts():
    text.set_color('white')
legend.get_title().set_color('white')
legend.get_title().set_weight('bold')
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_11352\2578869381.py:8: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   c=y["critical_temp"].ravel(), cmap="rocket", norm=norm, s=2, alpha=0.6)

# %%
x = list(range(0,1000))
y = list(range(0,1000))

x = (0,1,2,3,4,5)
y = (0,1,2,3,4,5)

sns.scatterplot(x=x, y=y, hue=np.array(y), palette="rocket")
# Out:
# <Axes: >

# %% [markdown]
# Dimensions from 2 to 4 plot

# %%
feature_names = df.columns

coeff_3 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=2)

coeff_4 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=3)

coeff_5 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=4)
# Out:
# Coefficients for Dimension 2:
# {'wtd_entropy_ThermalConductivity': -0.24517858495200542, 'wtd_std_Valence': -0.23150078903928342, 'range_Valence': -0.22608712003266504, 'std_Valence': -0.2100471784704598, 'wtd_entropy_fie': -0.2060966801882916, 'entropy_ThermalConductivity': -0.20404171370219498, 'wtd_entropy_ElectronAffinity': -0.19292305594193795, 'range_FusionHeat': -0.18255227462019621, 'wtd_std_FusionHeat': -0.18001354265765185, 'std_FusionHeat': -0.17123241465749664, 'std_Density': -0.15784991969360912, 'wtd_range_fie': 0.14691549569818776, 'wtd_entropy_Density': -0.1455748178176735, 'range_Density': -0.14473119440246743, 'range_ElectronAffinity': -0.14448925112095595, 'mean_FusionHeat': -0.14202176234228664, 'wtd_mean_FusionHeat': -0.13626745505831486, 'std_ElectronAffinity': -0.13196387223411332, 'wtd_std_Density': -0.12952638547674672, 'gmean_fie': -0.12904908018557854, 'wtd_std_ElectronAffinity': -0.12731596155610403, 'wtd_mean_Valence': -0.12616061316833677, 'mean_ElectronAffinity': -0.12262594998245308, 'mean_Valence': -0.1218801343700731, 'std_ThermalConductivity': 0.11828183931591853, 'wtd_gmean_FusionHeat': -0.1167758573491498, 'std_atomic_mass': -0.11677030563943577, 'gmean_FusionHeat': -0.11117208174827645, 'wtd_gmean_Valence': -0.10880312628388138, 'mean_fie': -0.10828177555884642, 'wtd_std_ThermalConductivity': 0.10808018448369912, 'mean_atomic_radius': 0.10695329535777756, 'range_atomic_mass': -0.10593270105369038, 'wtd_entropy_Valence': -0.10412378473850387, 'range_ThermalConductivity': 0.10223113636992906, 'wtd_std_atomic_mass': -0.1011710203075471, 'wtd_mean_Density': -0.09789222811662406, 'gmean_Valence': -0.09746440403652218, 'entropy_fie': -0.09526729296594685, 'wtd_range_FusionHeat': -0.09448826544937933, 'entropy_atomic_radius': -0.09326826032908461, 'entropy_ElectronAffinity': -0.09173734152511441, 'entropy_Density': -0.08292546054628373, 'gmean_ElectronAffinity': -0.08042527638689345, 'wtd_entropy_FusionHeat': -0.07842078213935191, 'number_of_elements': -0.07519712091368758, 'wtd_entropy_atomic_radius': -0.07503501851588282, 'mean_Density': -0.0742377006063179, 'wtd_range_ThermalConductivity': 0.07394827630849377, 'gmean_atomic_radius': 0.07308429558076476, 'entropy_Valence': -0.0713025212621307, 'mean_ThermalConductivity': 0.06840063988559819, 'wtd_gmean_ThermalConductivity': -0.0667077435927772, 'wtd_mean_fie': 0.06661566136706633, 'wtd_gmean_Density': -0.06612854528593648, 'wtd_gmean_atomic_radius': -0.06573807334657022, 'wtd_range_Density': -0.06272109408271745, 'entropy_atomic_mass': -0.05972960712335464, 'wtd_gmean_fie': 0.05682791877398835, 'wtd_mean_atomic_radius': -0.055907891056292895, 'entropy_FusionHeat': -0.05536226222241383, 'wtd_mean_atomic_mass': -0.0550806642550785, 'gmean_Density': -0.05480408155229405, 'gmean_ThermalConductivity': -0.05150047512379571, 'wtd_range_atomic_mass': -0.05119458447869145, 'wtd_std_fie': 0.051186852500054364, 'wtd_entropy_atomic_mass': -0.04921636665956995, 'wtd_range_ElectronAffinity': 0.0484025435573116, 'wtd_range_Valence': -0.045755286019623365, 'wtd_std_atomic_radius': 0.03139449416107497, 'wtd_gmean_atomic_mass': -0.02865225481755266, 'gmean_atomic_mass': 0.0253254965744043, 'wtd_gmean_ElectronAffinity': 0.024490638810260753, 'wtd_mean_ThermalConductivity': 0.01798219011946531, 'range_atomic_radius': 0.014911412111393926, 'std_atomic_radius': 0.013802737492626631, 'wtd_range_atomic_radius': -0.011749558804670358, 'wtd_mean_ElectronAffinity': -0.0099421000760492, 'mean_atomic_mass': -0.007334315887144455, 'std_fie': 0.007238059184249992, 'range_fie': -0.0047325690634421914}
#
# Coefficients for Dimension 3:
# {'wtd_mean_ElectronAffinity': 0.2743027246666665, 'wtd_gmean_ElectronAffinity': 0.267797270571082, 'mean_ElectronAffinity': 0.26638431986622857, 'gmean_ElectronAffinity': 0.23034831340759068, 'wtd_range_ElectronAffinity': 0.20185126329991998, 'entropy_ThermalConductivity': -0.1942693026782272, 'mean_atomic_mass': 0.1830340258764253, 'wtd_std_Density': 0.17201133989062936, 'wtd_entropy_ThermalConductivity': -0.16710688020552858, 'std_Density': 0.16698246984410164, 'wtd_gmean_fie': 0.15143209277845823, 'gmean_atomic_mass': 0.15064367169220563, 'mean_fie': 0.15058419427447273, 'wtd_mean_atomic_mass': 0.14724811221411693, 'mean_Density': 0.14581453212765225, 'gmean_fie': 0.14485390460434733, 'range_Density': 0.14272345579766516, 'wtd_mean_fie': 0.1423988028024157, 'std_ElectronAffinity': 0.13642577704785908, 'wtd_std_ElectronAffinity': 0.11942156698373199, 'range_FusionHeat': -0.11838651597759393, 'wtd_std_atomic_mass': 0.11446310672417152, 'range_ElectronAffinity': 0.11425394835007945, 'entropy_Density': -0.11409090076584938, 'wtd_range_atomic_mass': 0.11203723355124298, 'wtd_gmean_atomic_mass': 0.10861815235359562, 'std_FusionHeat': -0.1072867940302206, 'wtd_mean_Density': 0.10521545670863015, 'mean_Valence': 0.10408934679015841, 'wtd_mean_Valence': 0.10280584462800571, 'wtd_gmean_Valence': 0.10149684001928073, 'wtd_range_Density': 0.099924510411578, 'gmean_ThermalConductivity': -0.09957479739836929, 'wtd_std_FusionHeat': -0.09940605061029725, 'std_atomic_mass': 0.0976177263614172, 'wtd_mean_FusionHeat': -0.09761513011476482, 'gmean_Valence': 0.09736193599329404, 'mean_FusionHeat': -0.09204073919377409, 'wtd_gmean_FusionHeat': -0.09036937687565924, 'wtd_range_fie': 0.08744220251411376, 'wtd_entropy_Density': -0.0836600208041716, 'wtd_range_FusionHeat': -0.08287505726613012, 'wtd_gmean_ThermalConductivity': -0.08180380006662444, 'wtd_entropy_fie': -0.07955512918325168, 'gmean_FusionHeat': -0.07431288720765236, 'entropy_FusionHeat': -0.07146302935950843, 'wtd_std_fie': 0.07123027316988986, 'std_fie': 0.07002489429329131, 'range_atomic_mass': 0.07001843423006812, 'wtd_mean_ThermalConductivity': -0.06535310480439438, 'wtd_gmean_atomic_radius': -0.06283571975616634, 'entropy_atomic_radius': -0.061181348547021834, 'wtd_range_Valence': 0.06109864460476993, 'gmean_Density': 0.06088941779495204, 'entropy_atomic_mass': -0.06044047235090788, 'wtd_mean_atomic_radius': -0.060177995045568, 'number_of_elements': -0.05764604206907312, 'entropy_fie': -0.057386722428602925, 'entropy_Valence': -0.05370927429560672, 'wtd_gmean_Density': 0.05076245978910693, 'range_fie': 0.0476652071183424, 'wtd_entropy_Valence': -0.04666707745981548, 'wtd_entropy_atomic_mass': -0.046402991873590975, 'wtd_entropy_ElectronAffinity': -0.043640490018504334, 'wtd_entropy_FusionHeat': -0.04281512195726388, 'std_ThermalConductivity': 0.039540686663082004, 'gmean_atomic_radius': -0.03727710884065347, 'std_Valence': 0.03507825382990296, 'wtd_entropy_atomic_radius': -0.033150716603602484, 'wtd_std_atomic_radius': 0.03098481506205271, 'mean_ThermalConductivity': -0.025534203434821053, 'entropy_ElectronAffinity': -0.02457960632664788, 'range_ThermalConductivity': 0.02162876328035727, 'mean_atomic_radius': -0.020316428400147014, 'range_Valence': 0.018673036519082743, 'wtd_range_atomic_radius': -0.01860200478825602, 'wtd_std_Valence': 0.01797650712831935, 'std_atomic_radius': 0.01735196150902493, 'wtd_std_ThermalConductivity': 0.016363764157192207, 'range_atomic_radius': 0.0021600657912974894, 'wtd_range_ThermalConductivity': -0.0006911685616623103}
#
# Coefficients for Dimension 4:
# {'wtd_mean_ThermalConductivity': 0.2968959560986191, 'mean_ThermalConductivity': 0.28711766360127244, 'wtd_range_ThermalConductivity': 0.26268198013303984, 'wtd_gmean_ThermalConductivity': 0.2145103281018642, 'wtd_range_FusionHeat': 0.1972584693663524, 'gmean_ThermalConductivity': 0.19684022269774049, 'wtd_mean_FusionHeat': 0.19374192196545748, 'mean_FusionHeat': 0.1904074182608869, 'wtd_gmean_FusionHeat': 0.18155640698959039, 'wtd_std_Valence': -0.16612332861156778, 'std_FusionHeat': 0.16440592668348067, 'gmean_FusionHeat': 0.15737198556070564, 'range_FusionHeat': 0.15725188259438247, 'std_ThermalConductivity': 0.15274695293827192, 'wtd_range_ElectronAffinity': 0.149506011330967, 'wtd_std_FusionHeat': 0.14904200137586943, 'wtd_std_ThermalConductivity': 0.1466002881223256, 'std_Density': 0.14386691967968, 'wtd_std_Density': 0.14174169685180005, 'range_ThermalConductivity': 0.14150796319139008, 'wtd_range_Density': 0.13988513990199478, 'range_Density': 0.13920367639253658, 'range_Valence': -0.13919836645170292, 'wtd_range_fie': 0.13860382409569766, 'mean_atomic_radius': 0.13114188703378651, 'std_Valence': -0.12279004519183757, 'wtd_gmean_ElectronAffinity': 0.11945084825354114, 'std_atomic_mass': 0.11034181845260524, 'gmean_fie': -0.10549196936817039, 'wtd_mean_ElectronAffinity': 0.1044691964694011, 'mean_fie': -0.10363227330512877, 'mean_Density': 0.09527386554422922, 'gmean_atomic_radius': 0.09410331004561617, 'range_atomic_mass': 0.08968886815964687, 'wtd_entropy_ElectronAffinity': -0.08778587338409304, 'wtd_entropy_fie': -0.07715564265418112, 'wtd_entropy_ThermalConductivity': -0.07346406088344921, 'wtd_std_atomic_mass': 0.07032288859369439, 'range_ElectronAffinity': -0.06863346919584976, 'wtd_mean_Density': 0.06834238045177869, 'std_atomic_radius': 0.06651591058940459, 'range_atomic_radius': 0.0622116363442808, 'wtd_range_Valence': 0.06156987654808685, 'gmean_Density': 0.053269662588998866, 'wtd_std_ElectronAffinity': -0.05306508922758738, 'wtd_range_atomic_radius': 0.05131426070789428, 'wtd_std_atomic_radius': 0.050143518653974976, 'wtd_gmean_Density': 0.04606701453808326, 'std_ElectronAffinity': -0.04558176496326803, 'wtd_gmean_atomic_mass': -0.044068981786435375, 'entropy_Density': 0.04381953591986051, 'wtd_range_atomic_mass': 0.04336208463617021, 'entropy_FusionHeat': 0.04185249451434531, 'wtd_gmean_fie': 0.03954807309962136, 'entropy_ThermalConductivity': 0.03638270419758845, 'mean_atomic_mass': 0.03507824707078662, 'entropy_Valence': 0.032327604294884786, 'wtd_mean_fie': 0.032181306052005865, 'wtd_mean_Valence': -0.030413595571073867, 'wtd_mean_atomic_mass': -0.02859203274766026, 'wtd_entropy_Density': -0.02651830038827783, 'wtd_gmean_atomic_radius': -0.02533611116385869, 'mean_Valence': -0.023947450399062306, 'range_fie': -0.019806666829937515, 'entropy_ElectronAffinity': 0.018951040913633335, 'entropy_fie': 0.018845081842717003, 'entropy_atomic_radius': 0.01837213938707782, 'wtd_entropy_Valence': -0.017474444769651015, 'std_fie': -0.017079346769407346, 'wtd_mean_atomic_radius': -0.016268213656794255, 'wtd_gmean_Valence': -0.012870601904692703, 'number_of_elements': 0.011545688113824398, 'mean_ElectronAffinity': -0.008733333562364916, 'wtd_entropy_FusionHeat': -0.0072133731959991895, 'wtd_std_fie': -0.004966621061428415, 'gmean_ElectronAffinity': 0.004734746565590829, 'gmean_Valence': -0.004336136008363245, 'gmean_atomic_mass': -0.0040612971328551455, 'wtd_entropy_atomic_radius': -0.003434936328095811, 'wtd_entropy_atomic_mass': 0.0021339470903520745, 'entropy_atomic_mass': -0.0009406547009345927}

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=X_pca[:, 3], ys=X_pca[:, 4], zs=X_pca[:, 2],
           c=y["critical_temp"].ravel(), cmap="rocket", s=2, alpha=0.6)

ax.set_xlabel('Dimension 3')
ax.set_ylabel('Dimension 4')
ax.set_zlabel('Dimension 2')
ax.set_title('3D PCA scatter for first 3 dimensions', color="white")

legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#f5c5ac', markersize=10, label='Low'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#c6004e', markersize=10, label='Medium'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#251432', markersize=10, label='High')
]

legend = ax.legend(handles=legend_elements, title="Critical temperature", loc='upper left', labels=['Low', 'Medium', 'High'])
for text in legend.get_texts():
    text.set_color('white')
legend.get_title().set_color('white')
legend.get_title().set_weight('bold')
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_22572\4166558176.py:4: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   c=y["critical_temp"].ravel(), cmap="rocket", s=2, alpha=0.6)

# %% [markdown]
# Dimensions 0 + 3 + 4

# %%
feature_names = df.columns

coeff_3 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=0)

coeff_4 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=3)

coeff_5 = get_features_name_from_dim(feature_names=feature_names, pca_model=pca, dimension=4)
# Out:
# Coefficients for Dimension 0:
# {'range_fie': -0.16278269975128798, 'range_atomic_radius': -0.1625313125561126, 'wtd_entropy_atomic_radius': -0.16230899266044596, 'wtd_std_fie': -0.16225561689631143, 'wtd_std_atomic_radius': -0.15936485443617038, 'entropy_Valence': -0.15770718742674522, 'wtd_entropy_atomic_mass': -0.1555796328493876, 'entropy_fie': -0.15549120718544474, 'wtd_entropy_Valence': -0.15497111081224954, 'number_of_elements': -0.15480509430951608, 'wtd_gmean_Density': 0.1543912131434352, 'std_fie': -0.1540907532268255, 'entropy_atomic_radius': -0.15230737234436795, 'gmean_Density': 0.14934174842597306, 'std_atomic_radius': -0.1486519018495139, 'wtd_gmean_Valence': 0.14596926784817743, 'entropy_atomic_mass': -0.14544717837303592, 'wtd_mean_Valence': 0.14403529863179895, 'range_ThermalConductivity': -0.1430128412747839, 'wtd_entropy_FusionHeat': -0.14224062138062643, 'gmean_Valence': 0.14034960233789828, 'mean_Valence': 0.13911262647961306, 'entropy_ElectronAffinity': -0.1387321540214891, 'wtd_std_ThermalConductivity': -0.13871303668656626, 'wtd_gmean_atomic_radius': 0.13664761916914242, 'std_ThermalConductivity': -0.13421836108032217, 'entropy_FusionHeat': -0.13341740801511998, 'wtd_mean_Density': 0.12986607765112773, 'wtd_mean_fie': -0.12773361435521696, 'range_atomic_mass': -0.12371518889460115, 'entropy_Density': -0.12110720486574433, 'wtd_gmean_atomic_mass': 0.1188707811267179, 'wtd_mean_atomic_radius': 0.11837998202247361, 'critical_temp': -0.1183160334213432, 'wtd_gmean_fie': -0.11617714341977796, 'wtd_entropy_Density': -0.11508338340430309, 'gmean_FusionHeat': 0.11465023352898032, 'wtd_gmean_FusionHeat': 0.11390639096878193, 'wtd_std_atomic_mass': -0.11172626105178218, 'wtd_entropy_fie': -0.10922543966509847, 'gmean_ThermalConductivity': 0.10885229003870386, 'mean_Density': 0.10797424754918906, 'wtd_range_Valence': 0.10736211413082486, 'wtd_gmean_ThermalConductivity': 0.1066541677469022, 'range_ElectronAffinity': -0.10330800898574075, 'wtd_std_ElectronAffinity': -0.10184665492013495, 'wtd_range_atomic_radius': 0.0998957097850003, 'wtd_mean_atomic_mass': 0.0982061022594798, 'std_atomic_mass': -0.09783535795361646, 'wtd_mean_FusionHeat': 0.09620293442364536, 'wtd_entropy_ElectronAffinity': -0.0953811102179171, 'mean_FusionHeat': 0.09355128440739104, 'wtd_range_Density': 0.092569287154198, 'std_ElectronAffinity': -0.09094403512683588, 'wtd_range_atomic_mass': 0.0872837367387182, 'wtd_range_fie': -0.08449799872461976, 'gmean_atomic_mass': 0.08233025833354267, 'gmean_atomic_radius': 0.07733595981262739, 'wtd_range_FusionHeat': 0.0752178817262038, 'range_Density': -0.0749882498292058, 'wtd_std_Density': -0.07077928818173199, 'wtd_range_ElectronAffinity': -0.067852994728089, 'wtd_range_ThermalConductivity': -0.06189096967148355, 'wtd_mean_ElectronAffinity': -0.059792215318025435, 'gmean_ElectronAffinity': 0.056180739894057474, 'mean_fie': -0.056063897189352736, 'mean_ThermalConductivity': -0.05238286634846198, 'mean_atomic_mass': 0.05105309878267084, 'std_Density': -0.04036763157176965, 'entropy_ThermalConductivity': -0.03349553549309253, 'wtd_mean_ThermalConductivity': -0.03019908447342566, 'range_Valence': -0.0249882772907736, 'gmean_fie': -0.022742718270737754, 'std_FusionHeat': 0.020807681238578204, 'mean_atomic_radius': 0.020059317165438083, 'wtd_gmean_ElectronAffinity': -0.01234466896372833, 'wtd_std_FusionHeat': 0.01074460028375186, 'mean_ElectronAffinity': 0.007303640890143716, 'std_Valence': -0.00723406052685422, 'wtd_std_Valence': 0.004859358066364857, 'range_FusionHeat': 0.003634711085712056, 'wtd_entropy_ThermalConductivity': 0.0017160430635491056}
#
# Coefficients for Dimension 3:
# {'wtd_mean_ElectronAffinity': 0.2731138936718183, 'wtd_gmean_ElectronAffinity': 0.2672903131759188, 'mean_ElectronAffinity': 0.2632167774706824, 'gmean_ElectronAffinity': 0.22816676730005633, 'wtd_range_ElectronAffinity': 0.20185865246151988, 'entropy_ThermalConductivity': -0.19610098815492608, 'mean_atomic_mass': 0.18427219605942965, 'wtd_std_Density': 0.16964570230521345, 'wtd_entropy_ThermalConductivity': -0.1695243937828771, 'std_Density': 0.16387471401564946, 'gmean_atomic_mass': 0.15257524369370734, 'wtd_gmean_fie': 0.15170671083434123, 'wtd_mean_atomic_mass': 0.1474080526641098, 'mean_fie': 0.1472808904458138, 'mean_Density': 0.14460241319233758, 'wtd_mean_fie': 0.14308666010936488, 'gmean_fie': 0.14102869785729724, 'range_Density': 0.14026713602068086, 'std_ElectronAffinity': 0.13380736034411148, 'range_FusionHeat': -0.12391224723395242, 'wtd_std_ElectronAffinity': 0.11733159791142565, 'wtd_std_atomic_mass': 0.11335785868624128, 'entropy_Density': -0.11318618396459217, 'std_FusionHeat': -0.1130048259762363, 'range_ElectronAffinity': 0.11202003016162006, 'wtd_range_atomic_mass': 0.11153625901559693, 'wtd_gmean_atomic_mass': 0.10907303473784917, 'wtd_std_FusionHeat': -0.10487909305615856, 'wtd_mean_FusionHeat': -0.10321178232184, 'wtd_mean_Density': 0.10320912793068499, 'gmean_ThermalConductivity': -0.10251085328467684, 'mean_Valence': 0.101812800284251, 'wtd_mean_Valence': 0.10028502678577549, 'wtd_gmean_Valence': 0.09908482960599233, 'wtd_range_Density': 0.09785571607965593, 'mean_FusionHeat': -0.09766059849947838, 'std_atomic_mass': 0.09565896535210706, 'wtd_gmean_FusionHeat': -0.0953199291239776, 'gmean_Valence': 0.09531091155506803, 'wtd_range_fie': 0.0897574221229015, 'wtd_range_FusionHeat': -0.08759872687108756, 'wtd_gmean_ThermalConductivity': -0.08523053991602307, 'wtd_entropy_Density': -0.08378015179139317, 'wtd_entropy_fie': -0.08145289079941093, 'gmean_FusionHeat': -0.07863514691145804, 'wtd_std_fie': 0.07274438174555509, 'std_fie': 0.07032298572316709, 'entropy_FusionHeat': -0.07008358351298996, 'range_atomic_mass': 0.06867508888583969, 'wtd_mean_ThermalConductivity': -0.06791290154121062, 'wtd_gmean_atomic_radius': -0.06359728035553877, 'wtd_mean_atomic_radius': -0.06068816797036655, 'entropy_atomic_radius': -0.06066047434572842, 'wtd_range_Valence': 0.059852898645302785, 'gmean_Density': 0.059831182049875704, 'entropy_atomic_mass': -0.05901849928474176, 'number_of_elements': -0.057139414618730545, 'entropy_fie': -0.05707258786380589, 'entropy_Valence': -0.05316966561732359, 'wtd_gmean_Density': 0.049243672793336836, 'range_fie': 0.048097729677664416, 'wtd_entropy_Valence': -0.046821329452479694, 'wtd_entropy_atomic_mass': -0.045619519846513995, 'wtd_entropy_ElectronAffinity': -0.04470257808791648, 'wtd_entropy_FusionHeat': -0.042034714734741914, 'std_ThermalConductivity': 0.04102149594101688, 'critical_temp': -0.03781618252008269, 'gmean_atomic_radius': -0.03467715541593835, 'std_Valence': 0.03314888495510954, 'wtd_entropy_atomic_radius': -0.032701179687971246, 'wtd_std_atomic_radius': 0.03155837786286983, 'mean_ThermalConductivity': -0.026748137836867553, 'entropy_ElectronAffinity': -0.023782750592274617, 'range_ThermalConductivity': 0.023143902821670604, 'wtd_range_atomic_radius': -0.0190185762201742, 'wtd_std_ThermalConductivity': 0.01760704460509258, 'mean_atomic_radius': -0.0173222747001013, 'std_atomic_radius': 0.01709014677989082, 'range_Valence': 0.01678931857620792, 'wtd_std_Valence': 0.016103742966156517, 'range_atomic_radius': 0.0024130117084487346, 'wtd_range_ThermalConductivity': -0.0016394211341778054}
#
# Coefficients for Dimension 4:
# {'wtd_mean_ThermalConductivity': 0.2984551951996441, 'mean_ThermalConductivity': 0.2857924286154685, 'wtd_range_ThermalConductivity': 0.26274306654277063, 'wtd_gmean_ThermalConductivity': 0.21558529482397087, 'wtd_range_FusionHeat': 0.19863181205661495, 'gmean_ThermalConductivity': 0.19682999743834131, 'wtd_mean_FusionHeat': 0.19663804402097892, 'mean_FusionHeat': 0.19356707962790806, 'wtd_gmean_FusionHeat': 0.1841272368016016, 'std_FusionHeat': 0.1668152156454833, 'wtd_std_Valence': -0.16384705241357767, 'gmean_FusionHeat': 0.15985280299595891, 'range_FusionHeat': 0.15920382799503077, 'wtd_std_FusionHeat': 0.15116280938437301, 'std_ThermalConductivity': 0.15009982678880454, 'wtd_range_ElectronAffinity': 0.14710533038144766, 'std_Density': 0.14706955304091443, 'wtd_std_ThermalConductivity': 0.1447433138832378, 'wtd_std_Density': 0.14374692881910944, 'wtd_range_Density': 0.14209257943127596, 'range_Density': 0.14116628520247462, 'range_ThermalConductivity': 0.1385659714257758, 'range_Valence': -0.13748268037193231, 'wtd_range_fie': 0.13185895448727092, 'mean_atomic_radius': 0.12457259403703606, 'std_Valence': -0.1209983069058161, 'wtd_gmean_ElectronAffinity': 0.11887110698816526, 'std_atomic_mass': 0.11186616721571362, 'wtd_mean_ElectronAffinity': 0.10575267497878973, 'mean_Density': 0.09713982826272431, 'gmean_fie': -0.09569913876873498, 'mean_fie': -0.09461510889115911, 'range_atomic_mass': 0.0903584044929949, 'gmean_atomic_radius': 0.0883278104372188, 'wtd_entropy_ElectronAffinity': -0.08648730670138022, 'critical_temp': 0.08035903692196114, 'wtd_entropy_fie': -0.07406804947046551, 'wtd_entropy_ThermalConductivity': -0.07313489277716899, 'wtd_mean_Density': 0.07209186042199889, 'wtd_std_atomic_mass': 0.07098982870665013, 'std_atomic_radius': 0.06564007919064217, 'range_ElectronAffinity': -0.06355870738958472, 'wtd_range_Valence': 0.06123966698632874, 'range_atomic_radius': 0.06071880197016922, 'gmean_Density': 0.05450190405876657, 'wtd_range_atomic_radius': 0.050974785465459214, 'wtd_gmean_Density': 0.048504618536480096, 'wtd_std_atomic_radius': 0.048335907851976966, 'wtd_std_ElectronAffinity': -0.04803543011433628, 'wtd_range_atomic_mass': 0.04438543858117681, 'wtd_gmean_atomic_mass': -0.04160219318287977, 'std_ElectronAffinity': -0.039628768598843456, 'wtd_gmean_fie': 0.038709789370573434, 'entropy_Density': 0.03848882457722395, 'entropy_FusionHeat': 0.03724154436346988, 'mean_atomic_mass': 0.03493614636018651, 'entropy_ThermalConductivity': 0.03357907008269583, 'wtd_mean_fie': 0.0309261171181331, 'entropy_Valence': 0.029141630837961653, 'wtd_entropy_Density': -0.028493450633010207, 'wtd_mean_Valence': -0.026263413996754557, 'wtd_mean_atomic_mass': -0.02575199527845852, 'wtd_gmean_atomic_radius': -0.022856431397997378, 'mean_Valence': -0.020085154023915478, 'range_fie': -0.01963227153492116, 'wtd_entropy_Valence': -0.017856989128464777, 'std_fie': -0.01653078139994125, 'entropy_fie': 0.01581231557314573, 'entropy_atomic_radius': 0.014944803826317656, 'entropy_ElectronAffinity': 0.014640874903400887, 'wtd_mean_atomic_radius': -0.013831984717308388, 'wtd_entropy_FusionHeat': -0.009439244277131265, 'gmean_ElectronAffinity': 0.009033597057374018, 'wtd_gmean_Valence': -0.008925274628250619, 'number_of_elements': 0.008908115528378061, 'wtd_std_fie': -0.006717182228806577, 'wtd_entropy_atomic_radius': -0.005590308517056788, 'entropy_atomic_mass': -0.005239900541800016, 'gmean_atomic_mass': -0.004762842743524407, 'mean_ElectronAffinity': -0.0019657650080027334, 'gmean_Valence': -0.0007938620600474195, 'wtd_entropy_atomic_mass': -0.000304827814213913}

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=X_pca[:, 0], ys=X_pca[:, 3], zs=X_pca[:, 4],
           c=y["critical_temp"].ravel(), cmap="rocket", s=2, alpha=0.6)

ax.set_xlabel('Dimension 0')
ax.set_ylabel('Dimension 3')
ax.set_zlabel('Dimension 4')
ax.set_title('3D PCA scatter for first 3 dimensions', color="white")

legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#f5c5ac', markersize=10, label='Low'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#c6004e', markersize=10, label='Medium'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='#251432', markersize=10, label='High')
]

legend = ax.legend(handles=legend_elements, title="Critical temperature", loc='upper left', labels=['Low', 'Medium', 'High'])
for text in legend.get_texts():
    text.set_color('white')
legend.get_title().set_color('white')
legend.get_title().set_weight('bold')
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_22572\2027381816.py:4: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   c=y["critical_temp"].ravel(), cmap="rocket", s=2, alpha=0.6)
